# %% [markdown]
# <a href="https://colab.research.google.com/github/seunghwan1228/Convolution_practice/blob/master/ImageDataGenerator2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from keras.preprocessing import image

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
datagen = ImageDataGenerator(rotation_range = 40,
                             height_shift_range = 0.2, 
                             shear_range = 0.2,
                             horizontal_flip = True,
                             vertical_flip = True,
                             )

# %%
len(os.listdir('/content/drive/My Drive/input/Cats_vs_Dogs/cats vs dogs valid/Dogs'))
# Out:
# 501

# %%
datagen.flow_from_directory('/content/drive/My Drive/input/Cats_vs_Dogs/cats vs dogs valid', target_size = (150,150), class_mode = 'binary', batch_size = 32)
# Out:
# Found 1002 images belonging to 2 classes.

# %%
data = plt.imread('/content/drive/My Drive/input/Cats_vs_Dogs/cats vs dogs valid/Cats/cat.152.jpg')

# %%
plt.imshow(data)

# %%
img = image.load_img('/content/drive/My Drive/input/Cats_vs_Dogs/cats vs dogs valid/Cats/cat.152.jpg', target_size=(150,150))

img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FA0CEB94F60>

# %%
x = image.img_to_array(img)

# %%
x
# Out:
# array([[[ 95., 154., 248.],
#         [ 96., 155., 249.],
#         [ 95., 154., 244.],
#         ...,
#         [ 78., 134., 217.],
#         [ 33.,  61., 134.],
#         [ 32.,  79., 151.]],
#
#        [[ 91., 149., 246.],
#         [ 94., 153., 247.],
#         [ 71., 130., 222.],
#         ...,
#         [ 74., 128., 218.],
#         [ 31.,  56., 136.],
#         [ 33.,  73., 143.]],
#
#        [[ 91., 149., 246.],
#         [ 99., 157., 254.],
#         [ 85., 144., 236.],
#         ...,
#         [ 87., 138., 229.],
#         [ 31.,  53., 136.],
#         [ 30.,  67., 137.]],
#
#        ...,
#
#        [[103., 168., 250.],
#         [ 94., 159., 241.],
#         [106., 171., 253.],
#         ...,
#         [ 97., 159., 246.],
#         [103., 164., 245.],
#         [104., 161., 250.]],
#
#        [[108., 173., 255.],
#         [ 94., 159., 243.],
#         [108., 173., 255.],
#         ...,
#         [ 89., 154., 244.],
#         [ 92., 157., 241.],
# ...

# %%
x.shape
# Out:
# (150, 150, 3)

# %%
label = np.array([1])

# %%
print(label.shape)
label
# Out:
# (1,)
# array([1])

# %%
x = x.reshape((1,) + x.shape)

# %%
x.shape
# Out:
# (1, 150, 150, 3)

# %%
i = 0
for batch in datagen.flow(x, batch_size=1):
  plt.figure(i)
  imgplot = plt.imshow(image.array_to_img(batch[0]))
  
  i += 1
  if i % 10 == 0:
    break

plt.show()

# %%
j = 0
for i in datagen.flow(x, label, batch_size=1):
  print(i)
  print(i[0].shape)
  j += 1
  if j % 4 == 0:
    break
# Out:
# (array([[[[ 95.130455, 161.47827 , 246.04355 ],
#          [ 96.82605 , 163.6521  , 253.95628 ],
#          [ 93.69598 , 163.174   , 250.04396 ],
#          ...,
#          [107.63962 , 171.81981 , 255.      ],
#          [ 98.982574, 162.98257 , 249.26164 ],
#          [ 97.      , 161.      , 248.      ]],
#
#         [[ 95.08382 , 161.45029 , 245.885   ],
#          [ 96.81672 , 163.63344 , 253.90033 ],
#          [ 93.733284, 163.18332 , 250.09993 ],
#          ...,
#          [107.620964, 171.81049 , 255.      ],
#          [ 99.085175, 163.08517 , 249.32693 ],
#          [ 97.      , 161.      , 248.      ]],
#
#         [[ 95.037186, 161.42232 , 245.72643 ],
#          [ 96.807396, 163.61479 , 253.84436 ],
#          [ 93.77059 , 163.19264 , 250.1559  ],
#          ...,
#          [107.60231 , 171.80115 , 255.      ],
#          [ 99.187775, 163.18777 , 249.39221 ],
#          [ 97.      , 161.      , 248.      ]],
#
#         ...,
#
# ...

# %%
datagen.flow_from_directory('/content/drive/My Drive/input/Cats_vs_Dogs/Testing', target_size=(150, 150), class_mode='binary', batch_size=1)
# Out:
# Found 4 images belonging to 2 classes.

# %%
j = 0
for i in datagen.flow_from_directory('/content/drive/My Drive/input/Cats_vs_Dogs/Testing', target_size=(150, 150), class_mode='binary', batch_size=1):
  print(i)
  print(i[0])
  print(i[0].shape)
  plt.figure()
  img_show = plt.imshow(image.array_to_img(i[0].reshape(150,150,3)))
  plt.title(i[1])
  
  j += 1
  if j % 3 == 0:
    break
# Out:
# Found 4 images belonging to 2 classes.
# (array([[[[9.2815308e+01, 4.1020210e+01, 1.2900451e+00],
#          [8.4641518e+01, 3.5438110e+01, 9.3880884e-02],
#          [7.8121155e+01, 3.1325722e+01, 1.6534251e+00],
#          ...,
#          [1.7457695e+02, 1.6957695e+02, 1.4966797e+02],
#          [1.7450722e+02, 1.6950722e+02, 1.4979759e+02],
#          [1.7292166e+02, 1.6792166e+02, 1.4841139e+02]],
#
#         [[1.1522277e+02, 5.5373764e+01, 5.8044553e+00],
#          [1.2484354e+02, 6.2893147e+01, 5.9771032e+00],
#          [1.1666975e+02, 5.7311047e+01, 4.7809386e+00],
#          ...,
#          [1.8235023e+02, 1.7735023e+02, 1.5557120e+02],
#          [1.8052890e+02, 1.7552890e+02, 1.5414859e+02],
#          [1.8129213e+02, 1.7629213e+02, 1.5531053e+02]],
#
#         [[7.8169472e+01, 2.8754204e+01, 1.0282448e+01],
#          [7.6163956e+01, 2.4907885e+01, 5.0232792e+00],
#          [8.6131989e+01, 3.2682953e+01, 5.2226400e+00],
#          ...,
# ...
